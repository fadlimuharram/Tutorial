# %% [markdown]
# ### Image Processing Class With opencv
# Why we use opencv ....?
#
# Opencv contains:
# 1. Image processing algoritms (from image grayscaling to Surf Algrithm)
# 2. Machine Learning algorithms
# 3. Computer vision (image features: LBP, Hog, fischerface, facerecog, background modelling, yolo)
#
# Opencv Languages:
# 1. c++
# 2. python
# 3. c# (emgucv)
#
# Opencv Installation:
# 1. pip install opencv (python): a lazy method, sometimes error in showing image
# 2. build using cmake (recomended)

# %%
# import opencv
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# #### The most fundamental
#
# 1. The concept of image
# 2. Hello world in image processing: image grayscaling

# %%
img = cv2.imread('download.jpeg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
print(img.shape)
plt.imshow(img)
plt.show()
# Out:
# (207, 243, 3)

# %%
img_gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
plt.imshow(img_gray)
plt.show()

# %% [markdown]
# #### The next step
# 1. Image binarization techniques: mean vs gaussian vs otsu method
# 2. Image edge detection: Canny vs sobel
# 3. image smoothing/denoising: gaussian vs median

# %%
# mean method
th_mean = cv2.adaptiveThreshold(img_gray, 255, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY, 11, 2)
plt.imshow(th_mean)
plt.show()

# %%
# gaussian method
th_gaussian = cv2.adaptiveThreshold(img_gray, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, 11, 2)
plt.imshow(th_gaussian)
plt.show()

# %%
# otsu method
ret2,th_otsu = cv2.threshold(img_gray, 0, 255, cv2.THRESH_BINARY+cv2.THRESH_OTSU)
plt.imshow(th_otsu)
plt.show()

# %% [markdown]
# ||||||||||||||
# Now Edge Detection
# ||||||||||||||

# %%
# canny edge
canny = cv2.Canny(img_gray, 100, 200)
plt.imshow(canny)
plt.show()

# %%
# sobel
sobelx = cv2.Sobel(img_gray,cv2.CV_64F,1,0,ksize=5)
sobely = cv2.Sobel(img_gray,cv2.CV_64F,0,1,ksize=5)
plt.imshow(sobelx)
plt.show()
plt.imshow(sobely)
plt.show()

# %% [markdown]
# ||||||||||||||
# Now Image Denoising
# ||||||||||||||

# %%
kernel = np.ones((5,5),np.float32)/25
dst = cv2.filter2D(img, -1, kernel)
plt.imshow(dst)
plt.show()
